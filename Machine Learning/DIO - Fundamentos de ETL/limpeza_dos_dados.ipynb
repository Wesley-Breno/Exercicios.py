# %%
import pandas as pd
import pandera as pa

# %%
df = pd.read_csv('file.csv', parse_dates=['ocorrencia_data'], dayfirst=True)

# %%
df.replace(['None'], pd.NA, inplace=True)
df.fillna(0, inplace=True)

# %%
df.replace([0], pd.NA, inplace=True)
df
# Out:
#     codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0                   1                  11                     <NA>
# 1                   2                  22                 Acidente
# 2                   3                  33                Incidente
# 3                   4                  44                 Acidente
# 4                   5                  55                Incidente
# 5                   6                  66                 Acidente
# 6                   7                  77                Incidente
# 7                   8                  88                 Acidente
# 8                   9                  99                Incidente
# 9                  10                1010                 Acidente
# 10                 10                1010                 Acidente
#
#    ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_data  \
# 0     Rio de Janeiro            RJ                 <NA>      2022-11-01
# 1          São Paulo            SP                 SBSP      2022-01-02
# 2     Belo Horizonte            MG                 <NA>      2022-01-03
# 3             Recife            PE                 SBRF      2022-01-04
# 4           Brasília            DF                 SBBR      2022-01-05
# 5       Porto Alegre            RS                 <NA>      2022-01-06
# 6           Curitiba            PR                 SBCT      2022-01-07
# 7           Salvador            BA                 SBSV      2022-01-08
# 8             Manaus            AM                 <NA>      2022-01-09
# 9            Goiânia            GO                 SBGO      2022-01-10
# 10           Goiânia            GO                 SBGO      2022-01-10
#
#    ocorrencia_horario
# 0               14:30
# 1               10:15
# 2               08:45
# 3               16:20
# 4               12:10
# 5               09:05
# 6               18:30
# 7               11:40
# 8               13:25
# 9               15:50
# 10              15:50

# %%
df.fillna(value={'ocorrencia_aerodromo': 69})
# Out:
#     codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0                   1                  11                     <NA>
# 1                   2                  22                 Acidente
# 2                   3                  33                Incidente
# 3                   4                  44                 Acidente
# 4                   5                  55                Incidente
# 5                   6                  66                 Acidente
# 6                   7                  77                Incidente
# 7                   8                  88                 Acidente
# 8                   9                  99                Incidente
# 9                  10                1010                 Acidente
# 10                 10                1010                 Acidente
#
#    ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_data  \
# 0     Rio de Janeiro            RJ                   69      2022-11-01
# 1          São Paulo            SP                 SBSP      2022-01-02
# 2     Belo Horizonte            MG                   69      2022-01-03
# 3             Recife            PE                 SBRF      2022-01-04
# 4           Brasília            DF                 SBBR      2022-01-05
# 5       Porto Alegre            RS                   69      2022-01-06
# 6           Curitiba            PR                 SBCT      2022-01-07
# 7           Salvador            BA                 SBSV      2022-01-08
# 8             Manaus            AM                   69      2022-01-09
# 9            Goiânia            GO                 SBGO      2022-01-10
# 10           Goiânia            GO                 SBGO      2022-01-10
#
#    ocorrencia_horario
# 0               14:30
# 1               10:15
# 2               08:45
# 3               16:20
# 4               12:10
# 5               09:05
# 6               18:30
# 7               11:40
# 8               13:25
# 9               15:50
# 10              15:50

# %%
df['horario_2'] = df.ocorrencia_horario
df
# Out:
#     codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0                   1                  11                     <NA>
# 1                   2                  22                 Acidente
# 2                   3                  33                Incidente
# 3                   4                  44                 Acidente
# 4                   5                  55                Incidente
# 5                   6                  66                 Acidente
# 6                   7                  77                Incidente
# 7                   8                  88                 Acidente
# 8                   9                  99                Incidente
# 9                  10                1010                 Acidente
# 10                 10                1010                 Acidente
#
#    ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_data  \
# 0     Rio de Janeiro            RJ                 <NA>      2022-11-01
# 1          São Paulo            SP                 SBSP      2022-01-02
# 2     Belo Horizonte            MG                 <NA>      2022-01-03
# 3             Recife            PE                 SBRF      2022-01-04
# 4           Brasília            DF                 SBBR      2022-01-05
# 5       Porto Alegre            RS                 <NA>      2022-01-06
# 6           Curitiba            PR                 SBCT      2022-01-07
# 7           Salvador            BA                 SBSV      2022-01-08
# 8             Manaus            AM                 <NA>      2022-01-09
# 9            Goiânia            GO                 SBGO      2022-01-10
# 10           Goiânia            GO                 SBGO      2022-01-10
#
#    ocorrencia_horario horario_2
# 0               14:30     14:30
# 1               10:15     10:15
# 2               08:45     08:45
# 3               16:20     16:20
# 4               12:10     12:10
# 5               09:05     09:05
# 6               18:30     18:30
# 7               11:40     11:40
# 8               13:25     13:25
# 9               15:50     15:50
# 10              15:50     15:50

# %%
df.drop(['horario_2'], axis=1, inplace=True)

# %%
df
# Out:
#     codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0                   1                  11                     <NA>
# 1                   2                  22                 Acidente
# 2                   3                  33                Incidente
# 3                   4                  44                 Acidente
# 4                   5                  55                Incidente
# 5                   6                  66                 Acidente
# 6                   7                  77                Incidente
# 7                   8                  88                 Acidente
# 8                   9                  99                Incidente
# 9                  10                1010                 Acidente
# 10                 10                1010                 Acidente
#
#    ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_data  \
# 0     Rio de Janeiro            RJ                 <NA>      2022-11-01
# 1          São Paulo            SP                 SBSP      2022-01-02
# 2     Belo Horizonte            MG                 <NA>      2022-01-03
# 3             Recife            PE                 SBRF      2022-01-04
# 4           Brasília            DF                 SBBR      2022-01-05
# 5       Porto Alegre            RS                 <NA>      2022-01-06
# 6           Curitiba            PR                 SBCT      2022-01-07
# 7           Salvador            BA                 SBSV      2022-01-08
# 8             Manaus            AM                 <NA>      2022-01-09
# 9            Goiânia            GO                 SBGO      2022-01-10
# 10           Goiânia            GO                 SBGO      2022-01-10
#
#    ocorrencia_horario
# 0               14:30
# 1               10:15
# 2               08:45
# 3               16:20
# 4               12:10
# 5               09:05
# 6               18:30
# 7               11:40
# 8               13:25
# 9               15:50
# 10              15:50

# %%
df.drop_duplicates(inplace=True)
df.fillna(0, inplace=True)
