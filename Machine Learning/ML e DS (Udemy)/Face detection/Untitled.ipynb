# %% [markdown]
# <h1>Importing the necessary libraries</h1>

# %%
import cv2
from matplotlib import pyplot as plt

# %% [markdown]
# <h1>Loading image and showing on screen</h1>

# %%
image = cv2.imread('workplace-1245776_1920.jpg')

# %%
# Mostrando imagem
gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

plt.imshow(gray_image, cmap='gray')
plt.axis('off')
plt.show()

# %% [markdown]
# <h1>Creating face detector</h1>

# %%
face_detector = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')

# %% [markdown]
# <h1>Making detections in the image and showing it on the screen</h1>

# %%
detections = detector_face.detectMultiScale(gray_image, scaleFactor=1.3, minSize=(30,30))

# %%
for x, y, l, a in detections:
    image = cv2.rectangle(image, (x, y), (x + l, y + a), (0, 255, 0), 2)
plt.imshow(image)
